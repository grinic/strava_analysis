# %%
import os, glob
from datetime import date, timedelta
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from funcs import io
from importlib import reload

# %%
folder = os.path.join('..','data')
activities = io.load_dataset(folder, which='last', activity_type='Run')

# %% [markdown]
# # Extract data for marathons
#
# Assume that the training lasted 16 weeks.

# %%
reload(io)
# Out:
# <module 'funcs.io' from 'C:\\Users\\nicol\\Dropbox\\strava_analysis\\code\\funcs\\io.py'>

# %%
marathon_dates = [
    date(2022, 5, 8),
    date(2023, 3, 19)
]
training_time = 18 # in weeks
color_palette = {
    '2022':'tab:blue',
    '2023':'tab:orange'
}

# %%
marathons = io.extract_marathons(marathon_dates, training_time, activities)
# Out:
# 2022-05-08
# 2023-03-19

# %%
marathons.head()
# Out:
#                       name  distance  moving_time  elapsed_time  \
# 0  Zurich Marató Barcelona   42551.8        11210         11210
# 1              Evening Run    6062.0         1646          1646
# 2              Evening Run   10050.5         2841          2847
# 3              Evening Run   16143.5         4526          4526
# 4              Evening Run   11208.1         3114          3120
#
#    total_elevation_gain type sport_type            start_date  \
# 0                 145.0  Run        Run  2022-05-08T06:02:30Z
# 1                  53.0  Run        Run  2022-05-07T16:42:00Z
# 2                  70.0  Run        Run  2022-05-05T16:46:00Z
# 3                 110.0  Run        Run  2022-05-02T17:02:01Z
# 4                  52.0  Run        Run  2022-04-28T17:42:01Z
#
#   location_country  kudos_count  ...  average_heartrate  max_heartrate  \
# 0            Spain            7  ...              176.0          194.0
# 1            Spain            1  ...              163.8          183.0
# 2            Spain            1  ...              163.8          181.0
# 3            Spain            3  ...              159.8          172.0
# 4            Spain            1  ...              157.0          174.0
#
#   elev_high elev_low has_kudoed  suffer_score        date  days2race  \
# 0      65.6     10.4      False         588.0  2022-05-08          0
# 1      98.0     63.8      False          46.0  2022-05-07         -1
# 2     102.8     65.8      False          80.0  2022-05-05         -3
# 3     124.6     65.2      False         114.0  2022-05-02         -6
# 4     114.8     64.8      False          70.0  2022-04-28        -10
#
#    weeks2race  year
# 0           0  2022
# 1           0  2022
# 2           0  2022
# 3           0  2022
# 4          -1  2022
#
# [5 rows x 30 columns]

# %%
marathons.average_speed = marathons.average_speed*60*60/1000
marathons.distance = marathons.distance/1000
marathons.moving_time = marathons.moving_time/60
marathons.total_elevation_gain = marathons.total_elevation_gain/1000

# %% [markdown]
# # Analysis
#
# First, we are going to check some overall statistics, including the total number of training sessions.
#
# We also going to plot the distance, time, and elevation accumulated over all the training sessions.

# %%
fig, ax = plt.subplots(1,4, figsize=(10,4))
fig.subplots_adjust(wspace=0.5)

sns.barplot(
    data = marathons,
    x = marathons.year.unique(), 
    y = marathons.groupby(['year'])['distance'].count(),
    palette = color_palette,
    ax = ax[0]
)
ax[0].set_ylabel('Training sessions (N)')

sns.barplot(
    data = marathons,
    x = marathons.year.unique(), 
    y = marathons.groupby(['year'])['distance'].sum(),
    palette = color_palette,
    ax = ax[1]
)
ax[1].set_ylabel('Total distance (kms)')

sns.barplot(
    data = marathons,
    x = marathons.year.unique(), 
    y = marathons.groupby(['year'])['moving_time'].sum()/60,
    palette = color_palette,
    ax = ax[2]
)
ax[2].set_ylabel('Total time (hours)')

sns.barplot(
    data = marathons,
    x = marathons.year.unique(), 
    y = marathons.groupby(['year'])['total_elevation_gain'].sum(),
    palette = color_palette,
    ax = ax[3]
)
ax[3].set_ylabel('Total elevation (km)')

# visualize overall numbers
for a in ax:
    for i in a.containers:
        a.bar_label(i,)

# %% [markdown]
# From this, it looks like in 2023 I trained more than 2022, and accumulated more elevation gain.
#
# Rather than just looking at the total sum of these metrics, I can also check their distributions with violinplots:

# %%
fig, ax = plt.subplots(1,3, figsize=(7.5,4))
fig.subplots_adjust(wspace=0.5)

sns.swarmplot(
    data=marathons, x="year", y=marathons.distance, 
    color='white', size=3,
    ax=ax[0]
)
sns.violinplot(
    data=marathons, x="year", y=marathons.distance, 
    palette = color_palette,
    ax=ax[0], inner='quartile'
)
ax[0].set_ylabel('Distance (kms)')
ax[0].set_ylim(0,None)

sns.swarmplot(
    data=marathons, x="year", y=marathons.moving_time, 
    color='white', size=3, 
    ax=ax[1]
)
sns.violinplot(
    data=marathons, x="year", y=marathons.moving_time, 
    palette = color_palette,
    ax=ax[1], inner='quartile'
)
ax[1].set_ylabel('Time (hours)')
ax[1].set_ylim(0,None)

sns.swarmplot(
    data=marathons, x="year", y=marathons.total_elevation_gain, 
    color='white', size=3, 
    ax=ax[2]
)
sns.violinplot(
    data=marathons, x="year", y=marathons.total_elevation_gain, 
    palette = color_palette,
    ax=ax[2], inner='quartile'
)
ax[2].set_ylabel('Elevation gain (km)')
ax[2].set_ylim(0,None)
# Out:
# (0.0, 1.48434458028331)
# C:\Users\nicol\Anaconda3\envs\nicola-env\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 5.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
fig, ax = plt.subplots(1,3, figsize=(8,4))
fig.subplots_adjust(wspace=0.5)

sns.swarmplot(
    data=marathons, x="year", y=marathons.average_speed, 
    color='white', size=3, 
    ax=ax[0]
)
sns.violinplot(
    data=marathons, x="year", y=marathons.average_speed, 
    palette = color_palette,
    ax=ax[0], inner='quartile'
)
ax[0].set_ylabel('Speed (km/h)')

sns.swarmplot(
    data=marathons, x="year", y=marathons.average_heartrate, 
    color='white', size=3, 
    ax=ax[1]
)
sns.violinplot(
    data=marathons, x="year", y=marathons.average_heartrate, 
    palette = color_palette,
    ax=ax[1], inner='quartile'
)
ax[1].set_ylabel('Heart rate (bpm)')

sns.swarmplot(
    data=marathons, x="year", y=marathons.average_cadence, 
    color='white', size=3, 
    ax=ax[2]
)
sns.violinplot(
    data=marathons, x="year", y=marathons.average_cadence, 
    palette = color_palette,
    ax=ax[2], inner='quartile'
)
ax[2].set_ylabel('Cadence (spm)')
# Out:
# Text(531.9722222222223, 0.5, 'Cadence (spm)')

# %%
# fig, ax = plt.subplots(1,1, figsize=(8,4))
graph = sns.lmplot(data=marathons,x='average_speed',y='average_heartrate', hue='year',
    palette = color_palette,
                  order=2)
graph.axes[0, 0].set_xlabel('Average speed (km/h)')
graph.axes[0, 0].set_ylabel('Average heartrate (bpm)')
# Out:
# Text(41.19675347222223, 0.5, 'Average heartrate (bpm)')

# %%
df = marathons.groupby(['year','days2race']).sum()['distance'].reset_index()
df['distance_cumsum'] = marathons.groupby(['year','days2race']).sum().groupby(level=0)['distance'].cumsum().reset_index().distance
# df['days2race'] = df['days2race'].as_categorical()

fig, ax1 = plt.subplots(1,1)
ax2 = ax1.twinx()

width = 0.5
shift = -width/2
for year in set(df.year):
    ax2.bar(
        df[df.year==year].days2race+shift,
        df[df.year==year].distance,
        color = color_palette[year],
        alpha = 0.4,
        width = width
    )
    ax1.plot(
        df[df.year==year].days2race,
        df[df.year==year].distance_cumsum,
        '-o',
        color = color_palette[year]
    )
    shift += width

ax1.set_zorder(ax2.get_zorder()+1)
ax1.set_frame_on(False)

# ax1.legend_.remove()
ax1.set_xlabel('Days to race')
ax1.set_ylabel('Cumulative distance (km)')
ax1.set_xticks([-t for t in [*range(0,(training_time*7)+1,30)]])
ax2.set_ylabel('Distance (km)')
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_23656\1619962968.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df = marathons.groupby(['year','days2race']).sum()['distance'].reset_index()
# C:\Users\nicol\AppData\Local\Temp\ipykernel_23656\1619962968.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df['distance_cumsum'] = marathons.groupby(['year','days2race']).sum().groupby(level=0)['distance'].cumsum().reset_index().distance
# Text(0, 0.5, 'Distance (km)')

# %%
df = marathons.groupby(['year','weeks2race']).sum()['distance'].reset_index()
df['distance_cumsum'] = marathons.groupby(['year','weeks2race']).sum().groupby(level=0)['distance'].cumsum().reset_index().distance
# df['days2race'] = df['days2race'].as_categorical()

fig, ax1 = plt.subplots(1,1)
ax2 = ax1.twinx()

width = 0.3
shift = -width/2
for year in set(df.year):
    ax2.bar(
        df[df.year==year].weeks2race+shift,
        df[df.year==year].distance,
        color = color_palette[year],
        alpha = 0.4,
        width = width
    )
    ax1.plot(
        df[df.year==year].weeks2race,
        df[df.year==year].distance_cumsum,
        '-o',
        color = color_palette[year],
    )
    shift += width

ax1.set_zorder(ax2.get_zorder()+1)
ax1.set_frame_on(False)

# ax1.legend_.remove()
ax1.set_xlabel('Weeks to race')
ax1.set_ylabel('Cumulative distance (km)')
ax1.set_xticks(range(-training_time,1,2))
ax2.set_ylabel('Distance (km)')
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_23656\2586635341.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df = marathons.groupby(['year','weeks2race']).sum()['distance'].reset_index()
# C:\Users\nicol\AppData\Local\Temp\ipykernel_23656\2586635341.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df['distance_cumsum'] = marathons.groupby(['year','weeks2race']).sum().groupby(level=0)['distance'].cumsum().reset_index().distance
# Text(0, 0.5, 'Distance (km)')

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
# import numpy as np

# fig = plt.figure() #create overall container

# ax1 = fig.add_subplot(111) #add a 1 by 1 plot to the figure

# dday = date(*[int(d) for d in marathon2022_training.start_date.max()[:10].split('-')])
# ds = [ date(*[int(ymd) for ymd in date_str[:10].split('-')]) for date_str in marathon2022_training.start_date ]
# x = np.asarray([ str(d-dday).split(',')[0] for d in ds ] )  #convert data to numpy array
# for i in range(len(x)):
#     if ':' in x[i]:
#         x[i] = 0
#     else:
#         x[i] = int(x[i][:3])
# x = x.astype(int)
# y = np.asarray(marathon2022_training.average_speed)
# ax1.plot(x[::-1], y[::-1], '-o') #plot data points in scatter plot on ax1

# dday = date(*[int(d) for d in marathon2023_training.start_date.max()[:10].split('-')])
# ds = [ date(*[int(ymd) for ymd in date_str[:10].split('-')]) for date_str in marathon2023_training.start_date ]
# x = np.asarray([ str(d-dday).split(',')[0] for d in ds ] )  #convert data to numpy array
# for i in range(len(x)):
#     if ':' in x[i]:
#         x[i] = 0
#     else:
#         x[i] = int(x[i][:3])
# x = x.astype(int)
# y = np.asarray(marathon2023_training.average_speed)
# ax1.plot(x[::-1], y[::-1],'-o') #plot data points in scatter plot on ax1

# ax1.set_title('Average Speed over Time')
# fig.autofmt_xdate(rotation=45)
# #ax1.set_ylim([0,5])

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
# import numpy as np

# fig = plt.figure() #create overall container

# ax1 = fig.add_subplot(111) #add a 1 by 1 plot to the figure

# dday = date(*[int(d) for d in marathon2022_training.start_date.max()[:10].split('-')])
# ds = [ date(*[int(ymd) for ymd in date_str[:10].split('-')]) for date_str in marathon2022_training.start_date ]
# x = np.asarray([ str(d-dday).split(',')[0] for d in ds ] )  #convert data to numpy array
# for i in range(len(x)):
#     if ':' in x[i]:
#         x[i] = 0
#     else:
#         x[i] = int(x[i][:3])
# x = x.astype(int)
# y = np.asarray(marathon2022_training.distance/1000)
# ax1.plot(x[::-1], y[::-1], '-o') #plot data points in scatter plot on ax1

# dday = date(*[int(d) for d in marathon2023_training.start_date.max()[:10].split('-')])
# ds = [ date(*[int(ymd) for ymd in date_str[:10].split('-')]) for date_str in marathon2023_training.start_date ]
# x = np.asarray([ str(d-dday).split(',')[0] for d in ds ] )  #convert data to numpy array
# for i in range(len(x)):
#     if ':' in x[i]:
#         x[i] = 0
#     else:
#         x[i] = int(x[i][:3])
# x = x.astype(int)
# y = np.asarray(marathon2023_training.distance/1000)
# ax1.plot(x[::-1], y[::-1],'-o') #plot data points in scatter plot on ax1

# ax1.set_title('Distance over Time')
# fig.autofmt_xdate(rotation=45)
# #ax1.set_ylim([0,5])

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
# import numpy as np

# fig = plt.figure() #create overall container

# ax1 = fig.add_subplot(111) #add a 1 by 1 plot to the figure

# dday = date(*[int(d) for d in marathon2022_training.start_date.max()[:10].split('-')])
# ds = [ date(*[int(ymd) for ymd in date_str[:10].split('-')]) for date_str in marathon2022_training.start_date ]
# x = np.asarray([ str(d-dday).split(',')[0] for d in ds ] )  #convert data to numpy array
# for i in range(len(x)):
#     if ':' in x[i]:
#         x[i] = 0
#     else:
#         x[i] = int(x[i][:3])
# x = x.astype(int)
# y = np.asarray(marathon2022_training.elapsed_time/60/60)
# ax1.plot(x[::-1], y[::-1], '-o') #plot data points in scatter plot on ax1

# dday = date(*[int(d) for d in marathon2023_training.start_date.max()[:10].split('-')])
# ds = [ date(*[int(ymd) for ymd in date_str[:10].split('-')]) for date_str in marathon2023_training.start_date ]
# x = np.asarray([ str(d-dday).split(',')[0] for d in ds ] )  #convert data to numpy array
# for i in range(len(x)):
#     if ':' in x[i]:
#         x[i] = 0
#     else:
#         x[i] = int(x[i][:3])
# x = x.astype(int)
# y = np.asarray(marathon2023_training.elapsed_time/60/60)
# ax1.plot(x[::-1], y[::-1],'-o') #plot data points in scatter plot on ax1

# ax1.set_title('Elapsed time over Time')
# fig.autofmt_xdate(rotation=45)
# #ax1.set_ylim([0,5])
